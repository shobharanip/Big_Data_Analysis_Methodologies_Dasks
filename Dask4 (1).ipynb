# %%
! python -m pip install 'fsspec>=0.3.3'
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
import requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 140 kB 5.0 MB/s
# ...

# %%
! pip install requests
! pip install aiohttp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 271 kB 43.6 MB/s
# ...
#      |████████████████████████████████| 144 kB 46.2 MB/s
# ...
#      |████████████████████████████████| 94 kB 2.6 MB/s
# ...

# %%
df17 = dd.read_csv('https://data.cityofnewyork.us/resource/2bnn-yakx.csv', blocksize=None)  
df17
# Out:
# Dask DataFrame Structure:
#               summons_number plate_id registration_state plate_type issue_date violation_code vehicle_body_type vehicle_make issuing_agency street_code1 street_code2 street_code3 vehicle_expiration_date violation_location violation_precinct issuer_precinct issuer_code issuer_command issuer_squad violation_time time_first_observed violation_county violation_in_front_of_or_opposite house_number street_name intersecting_street date_first_observed law_section sub_division violation_legal_code days_parking_in_effect from_hours_in_effect to_hours_in_effect vehicle_color unregistered_vehicle vehicle_year meter_number feet_from_curb violation_post_code violation_description no_standing_or_stopping_violation hydrant_violation double_parking_violation
# npartitions=1
# ...

# %%
df17 = df.repartition(npartitions=33) 
df17
# Out:
# Dask DataFrame Structure:
#                summons_number plate_id registration_state plate_type issue_date violation_code vehicle_body_type vehicle_make issuing_agency street_code1 street_code2 street_code3 vehicle_expiration_date violation_location violation_precinct issuer_precinct issuer_code issuer_command issuer_squad violation_time time_first_observed violation_county violation_in_front_of_or_opposite house_number street_name intersecting_street date_first_observed law_section sub_division violation_legal_code days_parking_in_effect from_hours_in_effect to_hours_in_effect vehicle_color unregistered_vehicle vehicle_year meter_number feet_from_curb violation_post_code violation_description no_standing_or_stopping_violation hydrant_violation double_parking_violation
# npartitions=33
# ...

# %%
# inspecting the columns
df17.columns
# Out:
# Index(['summons_number', 'plate_id', 'registration_state', 'plate_type',
#        'issue_date', 'violation_code', 'vehicle_body_type', 'vehicle_make',
#        'issuing_agency', 'street_code1', 'street_code2', 'street_code3',
#        'vehicle_expiration_date', 'violation_location', 'violation_precinct',
#        'issuer_precinct', 'issuer_code', 'issuer_command', 'issuer_squad',
#        'violation_time', 'time_first_observed', 'violation_county',
#        'violation_in_front_of_or_opposite', 'house_number', 'street_name',
#        'intersecting_street', 'date_first_observed', 'law_section',
#        'sub_division', 'violation_legal_code', 'days_parking_in_effect',
#        'from_hours_in_effect', 'to_hours_in_effect', 'vehicle_color',
#        'unregistered_vehicle', 'vehicle_year', 'meter_number',
#        'feet_from_curb', 'violation_post_code', 'violation_description',
#        'no_standing_or_stopping_violation', 'hydrant_violation',
#        'double_parking_violation'],
# ...

# %%
# https://data.cityofnewyork.us/browse?q=parking+ticket 
# 2016 https://data.cityofnewyork.us/resource/kiv2-tbus.csv
# 2015 https://data.cityofnewyork.us/resource/c284-tqph.csv
# 2014 https://data.cityofnewyork.us/resource/jt7v-77mi.csv

# %%
df14 = dd.read_csv('https://data.cityofnewyork.us/resource/jt7v-77mi.csv', blocksize=None)  
df14
# Out:
# Dask DataFrame Structure:
#               summons_number plate_id registration_state plate_type issue_date violation_code vehicle_body_type vehicle_make issuing_agency street_code1 street_code2 street_code3 vehicle_expiration_date violation_location violation_precinct issuer_precinct issuer_code issuer_command issuer_squad violation_time time_first_observed violation_county violation_in_front_of_or_opposite house_number street_name intersecting_street date_first_observed law_section sub_division violation_legal_code days_parking_in_effect from_hours_in_effect to_hours_in_effect vehicle_color unregistered_vehicle vehicle_year meter_number feet_from_curb violation_post_code violation_description no_standing_or_stopping_violation hydrant_violation double_parking_violation
# npartitions=1
# ...

# %%
# common set shared by all 4 years
from functools import reduce

columns = [set(df14.columns),
    set(df17.columns)]
common_columns = list(reduce(lambda a, i: a.intersection(i), columns))
common_columns
# Out:
# ['intersecting_street',
#  'issuing_agency',
#  'street_code1',
#  'violation_time',
#  'meter_number',
#  'issuer_squad',
#  'time_first_observed',
#  'from_hours_in_effect',
#  'to_hours_in_effect',
#  'no_standing_or_stopping_violation',
#  'issuer_code',
#  'plate_id',
#  'house_number',
#  'issuer_command',
#  'hydrant_violation',
#  'street_code2',
#  'vehicle_expiration_date',
#  'feet_from_curb',
#  'vehicle_year',
#  'vehicle_color',
#  'violation_legal_code',
#  'sub_division',
#  'plate_type',
#  'date_first_observed',
#  'vehicle_make',
#  'violation_location',
#  'unregistered_vehicle',
#  'violation_in_front_of_or_opposite',
#  'violation_post_code',
#  'law_section',
#  'street_name',
#  'registration_state',
#  'days_parking_in_effect',
#  'street_code3',
#  'double_parking_violation',
#  'violation_code',
#  'violation_precinct',
#  'violation_county',
#  'vehicle_body_type',
#  'violation_description',
#  'issuer_precinct',
#  'summons_number',
#  'issue_date']

# %% [markdown]
# Common columns

# %%
# look at the common columns in FY17
# [] filter selected columns, head() - looks at the first few rows. By defult: 5 rows, can specify 10 rows
df17[common_columns].head()
# Out:
#   intersecting_street issuing_agency  street_code1 violation_time  \
# 0          BARNES AVE              V             0          0143A
# 1          BARNES AVE              V             0          0400P
# 2            COLN AVE              V             0          1211P
# 3                 NaN              T         59590          1217P
# 4              100 ST              V             0          1207P
#
#   meter_number issuer_squad time_first_observed from_hours_in_effect  \
# 0          NaN          NaN                 NaN                  NaN
# 1          NaN          NaN                 NaN                  NaN
# 2          NaN          NaN                 NaN                  NaN
# 3          NaN            J                 NaN                  NaN
# 4          NaN          NaN                 NaN                  NaN
#
#   to_hours_in_effect  no_standing_or_stopping_violation  ...  street_code3  \
# ...

# %%
# head() - default is to show top 5 row, can specify other number
df17[common_columns].head(10)
# Out:
#   intersecting_street issuing_agency  street_code1 violation_time  \
# 0          BARNES AVE              V             0          0143A
# 1          BARNES AVE              V             0          0400P
# 2            COLN AVE              V             0          1211P
# 3                 NaN              T         59590          1217P
# 4              100 ST              V             0          1207P
# 5               H AVE              V             0          1037A
# 6                 NaN              T             0          0101P
# 7                 NaN              T         31830          0602P
# 8                 NaN              T         14380          0814A
# 9                 NaN              T         35720          1238P
#
#   meter_number issuer_squad time_first_observed from_hours_in_effect  \
# 0          NaN          NaN                 NaN                  NaN
# 1          NaN          NaN                 NaN                  NaN
# ...

# %% [markdown]
# Dask cannot infer datatypes

# %%
df14[common_columns].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-b0e3d3948a6d> in <module>()
# ----> 1 df14[common_columns].head()
#
# /usr/local/lib/python3.7/dist-packages/dask/dataframe/core.py in head(self, n, npartitions, compute)
#     996             Whether to compute the result, default is True.
#     997         """
# --> 998         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#     999
#    1000     def _head(self, n, npartitions, compute, safe):
#
# /usr/local/lib/python3.7/dist-packages/dask/dataframe/core.py in _head(self, n, npartitions, compute, safe)
#    1029
#    1030         if compute:
# -> 1031             result = result.compute()
#    1032         return result
#    1033
#
# /usr/local/lib/python3.7/dist-packages/dask/base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# ...
